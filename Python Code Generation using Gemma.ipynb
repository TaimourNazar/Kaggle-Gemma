# %% [markdown]
# <a href="https://www.kaggle.com/code/taimour/python-code-generation-using-gemma-fundamental?scriptVersionId=196074403" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Python Code Generation using Gemma (Fundamental Level)
#
# In notebook we will check the cability of Gemma to generate python code.
#
# We will be using **gemma_instruct_2b_en** variant of Gemma modal.
#
# *Note: First we will use Modal to generate python code, then we will run that code to see how well it works.*

# %%
import keras
import keras_nlp

import os

#We have three options to use a backend with Keras "Jax", tensorflow" or "torch", but we will be using Jax in this notebook
os.environ["KERAS_BACKEND"] = "jax"

gemma_lm = keras_nlp.models.GemmaCausalLM.from_preset("gemma_instruct_2b_en")

#Get summary of the modal
gemma_lm.summary()
# Out:
# 2024-09-10 13:19:43.593317: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-10 13:19:43.593466: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-10 13:19:43.714134: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Attaching 'model.safetensors' from model 'keras/gemma/keras/gemma_instruct_2b_en/2' to your Kaggle notebook...
# Attaching 'model.safetensors.index.json' from model 'keras/gemma/keras/gemma_instruct_2b_en/2' to your Kaggle notebook...
# Attaching 'metadata.json' from model 'keras/gemma/keras/gemma_instruct_2b_en/2' to your Kaggle notebook...
# ...

# %%
gemma_lm.generate("write code to print hello world in python", max_length=100)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725974522.791643      24 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1725974522.867555      24 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1725974522.945150      24 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 'write code to print hello world in python\n\n```python\nprint("Hello world!")\n```\n\n**Output:**\n\n```\nHello world!\n```\n\n**Explanation:**\n\n* `print()` is a built-in Python function that prints the given argument to the console.\n* `"Hello world!"` is the string that we want to print.\n* `` is the string delimiter, which tells `print()` to print the argument on a single line.\n\n**Note'

# %%
#Now lets test the generated code

print("Hello world!")
# Out:
# Hello world!

# %%
gemma_lm.generate("write code to add two numbers in python", max_length=100)
# Out:
# 'write code to add two numbers in python\n\n```python\n# Define two numbers\nnum1 = 10\nnum2 = 20\n\n# Add the two numbers\nsum = num1 + num2\n\n# Print the sum\nprint(sum)\n```\n\n**Output:**\n\n```\n30\n```\n\n**Explanation:**\n\n1. We define two variables, `num1` and `num2`, with values 10 and 20, respectively'

# %%
#Now lets test the generated code

num1 = 10
num2 = 20

# Add the two numbers
sum = num1 + num2

# Print the sum
print(sum)
# Out:
# 30

# %%
gemma_lm.generate("write code to subtract two numbers in python", max_length=100)
# Out:
# 'write code to subtract two numbers in python\n\n```python\n# Define the two numbers to subtract\nnum1 = int(input("Enter the first number: "))\nnum2 = int(input("Enter the second number: "))\n\n# Subtract the two numbers\ndifference = num1 - num2\n\n# Print the difference\nprint("The difference between", num1, "and", num2, "is", difference)\n```\n\n**Example Usage:**\n\n```\nEnter the'

# %%
#Now lets test the generated code

#num1 = int(input("Enter the first number: "))
num1 = 20
#num2 = int(input("Enter the second number: "))
num2 = 10

# Subtract the two numbers
difference = num1 - num2

# Print the difference
print("The difference between", num1, "and", num2, "is", difference)
# Out:
# The difference between 20 and 10 is 10

# %%
gemma_lm.generate("write code to add three numbers in python", max_length=100)
# Out:
# 'write code to add three numbers in python\n\n```python\n# Define the three numbers to add\nnum1 = 10\nnum2 = 20\nnum3 = 30\n\n# Add the numbers together\ntotal = num1 + num2 + num3\n\n# Print the total\nprint(f"The total is: {total}")\n```\n\n**Output:**\n\n```\nThe total is: 60\n```\n\n**Explanation:**\n\n1.'

# %%
#Now lets test the generated code

num1 = 10
num2 = 20
num3 = 30

# Add the numbers together
total = num1 + num2 + num3

# Print the total
print(f"The total is: {total}")
# Out:
# The total is: 60

# %%
gemma_lm.generate("write code to add digits in three indices of array in python", max_length=164)
# Out:
# W0000 00:00:1725974551.696360      24 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# "write code to add digits in three indices of array in python\n\n```python\narr = [1, 2, 3, 4, 5]\n\n# Create a copy of the array so that we don't modify it\ncopy_arr = arr.copy()\n\n# Add digits in the first index of the array\ncopy_arr[0] += 2\n\n# Add digits in the second index of the array\ncopy_arr[1] += 3\n\n# Add digits in the third index of the array\ncopy_arr[2] += 4\n\n# Print the modified array\nprint(copy_arr)\n```\n\n**Output:**\n\n```\n[1, 4, 7, 8, 9]\n```\n\n**Explanation"

# %%
#Now lets test the generated code

arr = [1, 2, 3, 4, 5]

# Create a copy of the array so that we don't modify it
copy_arr = arr.copy()

# Add digits in the first index of the array
copy_arr[0] += 2

# Add digits in the second index of the array
copy_arr[1] += 3

# Add digits in the third index of the array
copy_arr[2] += 4

# Print the modified array
print(copy_arr)
# Out:
# [3, 5, 7, 4, 5]

# %%
gemma_lm.generate("write code to perform bubble sort on an array in python", max_length=200)
# Out:
# W0000 00:00:1725974575.597474      24 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 'write code to perform bubble sort on an array in python\n\n```python\ndef bubble_sort(nums):\n  for i in range(len(nums)):\n    for j in range(len(nums) - i - 1):\n      if nums[j] > nums[j + 1]:\n        nums[j], nums[j + 1] = nums[j + 1], nums[j]\n\ndef print_array(nums):\n  print(nums)\n\n# Example usage\nnums = [5, 2, 8, 3, 1]\nprint_array(bubble_sort(nums))\n```\n\n**Output:**\n\n```\n[1, 2, 3, 5, 8]\n```\n\n**Explanation:**\n\n* The `bubble_sort` function performs a single pass through the array, comparing adjacent elements.\n* If the current element is greater than the next'

# %%
#Now lets test the generated code

def bubble_sort(nums):
    for i in range(len(nums)):
        for j in range(len(nums) - i - 1):
            if nums[j] > nums[j + 1]:
                nums[j], nums[j + 1] = nums[j + 1], nums[j]

def print_array(nums):
    print(nums)

# Example usage
nums = [5, 2, 8, 3, 1]
print_array(bubble_sort(nums))
# Out:
# None

# %%
#Code gives None as output beacuse in Python if a funciton doesn't return anything then it implicity None.
#Lets add a return statement in bubble_sort fucntion to check accuracy of generated code by Gemma

def bubble_sort(nums):
    for i in range(len(nums)):
        for j in range(len(nums) - i - 1):
            if nums[j] > nums[j + 1]:
                nums[j], nums[j + 1] = nums[j + 1], nums[j]
    return nums
#Return statment added

def print_array(nums):
    print(nums)

# Example usage
nums = [5, 2, 8, 3, 1]
print_array(bubble_sort(nums))
# Out:
# [1, 2, 3, 5, 8]

# %%
#Output shows that array was sorted properly. 

#We only asked for the code but Gemma also gave us explanation and outputs for code
#Overall it is a great modal
